# %%
from nltk import word_tokenize
import os

# 数据读写文件路径
TextPath = "D:/DATA/parsed_text" 
OutTemplateFile_nltk = "D:/DATA/nltk_text/nltk"

# 最后修改时间：2022/8/4/23：28
# 最后修改者：熊翔翔

# 获取指定文件夹内的所有文件的绝对路径
# return type: List
def GetFilePath(DirPath):
    
    Res = []
    for FilePath, DirNames, FileNames in os.walk(DirPath):
        for FileName in FileNames:
            str_tmp = os.path.join(FilePath, FileName)
            Res.append(str_tmp)
            
    return Res

#分词
def Get_word_nltk(FilePath, OutPutFile):
    with open(FilePath,'r', encoding='gb18030', errors='ignore') as f:
        txt_data = f.readlines()
        txt_data=str(txt_data) 
        
    cutwords1 = word_tokenize(txt_data) #分词
    interpunctuations = [',', '.', ':', ';', '?', '(', ')', '[', ']', '&', '!', '*', '@', '#', '$', '%']   #定义标点符号列表
    cutwords2 = [word for word in cutwords1 if word not in interpunctuations]   #去除标点符号
    OutPutFile.write(str(cutwords2))

    return

def main():
    # 获取所有文件路径并依次遍历
    FilePaths = GetFilePath(TextPath)
    cnt = 0
    total = len(FilePaths)
    for FilePath in FilePaths:
        OutPutPath_nltk = OutTemplateFile_nltk + "_" + str(cnt) + ".txt"
        OutPutFile_nltk = open(OutPutPath_nltk, "w",encoding="utf-8")
        Get_word_nltk(FilePath, OutPutFile_nltk)
        # 输出程序完成百分比
        print("\r",end="")
        print(100* cnt//total, end="%")
        cnt += 1
        OutPutFile_nltk.close()
        
    print("done")

    return
        

if __name__ == "__main__":
    main()
